# %%
import plotly.graph_objects as go
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import h5py

# %% [markdown]
# ### Normal incidence

# %%
num_bins = 8000
inc_e = 55000

                         
# # old
# el = pd.read_hdf('data/Al_BSE_mode:DS_tilt:0.0_tolE:0.0001_tolW:1e-07.h5', 'all_electrons')

# energyDS = list(el[el.values=='backscattered']['energy'])

# print ('yield of old discretly scattered BSE', len(energyDS)/inc_e)


# #bins_mean = [0.5 * (bins_c[i] + bins_c[i+1]) for i in range(len(n_c)-1)]

# n_d, bins_d, patches_d = plt.hist([float(energy) for energy in energyDS], num_bins, facecolor='blue', alpha=0.5)

# bins_mean = [0.5 * (bins_d[i] + bins_d[i+1]) for i in range(len(n_d)-1)]

# trace_discr_old = go.Scatter(x = np.asarray(bins_mean), 
#                            y = n_d/inc_e, 
#                           marker=dict(
#                                  color = 'rgba(10, 17, 212 .9)',),
#                           name = 'discrete old',)

# new
el = pd.read_hdf('data/Al_BSE_mode:DS_tilt:0.0_tolE:0.0001_tolW:1e-07_maxScat:1000.h5', 'electrons')

energyDS = list(el[el.outcome=='backscattered']['final_E'])

print ('yield of new discretly scattered BSE', len(energyDS)/inc_e)


#bins_mean = [0.5 * (bins_c[i] + bins_c[i+1]) for i in range(len(n_c)-1)]

n_d, bins_d, patches_d = plt.hist([float(energy) for energy in energyDS], num_bins, facecolor='red', alpha=0.5)

bins_mean = [0.5 * (bins_d[i] + bins_d[i+1]) for i in range(len(n_d)-1)]

trace_discr_new = go.Scatter(x = np.asarray(bins_mean), 
                           y = n_d/inc_e, 
                          marker=dict(
                                 color = 'rgba(10, 174, 212 .9)',),
                          name = 'discrete new',)

# cont
el = pd.read_hdf('data/Al_BSE_mode:cont_tilt:0.0_tolE:0.0001_tolW:1e-07_maxScat:1000.h5', 'electrons')

energyDS = list(el[el.outcome=='backscattered']['final_E'])

print ('yield of continuosly scattered BSE', len(energyDS)/inc_e)


#bins_mean = [0.5 * (bins_c[i] + bins_c[i+1]) for i in range(len(n_c)-1)]

n_d, bins_d, patches_d = plt.hist([float(energy) for energy in energyDS], num_bins, facecolor='red', alpha=0.5)

bins_mean = [0.5 * (bins_d[i] + bins_d[i+1]) for i in range(len(n_d)-1)]

trace_cont = go.Scatter(x = np.asarray(bins_mean), 
                           y = n_d/inc_e, 
                          marker=dict(
                                 color = 'rgba(10, 14, 212 .9)',),
                          name = 'cont',)
# Out:
# yield of new discretly scattered BSE 0.22934545454545455
# yield of continuosly scattered BSE 0.16785454545454545

# %%
dataframe = pd.read_hdf('data/Al_BSE_mode:DS_tilt:0.0_tolE:0.0001_tolW:1e-07_maxScat:1000.h5', 'input')

dataframe.head(100)
# Out:
#   num_el     E0  Emin material s_tilt mode Bethe_model   tol_E  tol_W  \
# 0   5000  20000  5000       Al      0   DS   classical  0.0001  1e-07
#
#   maxScatt  Wc     electron_output               scatter_output  L delta x_PC  \
# 0     1000  10  [outcome, final_E]  [type, az_angle, pol_angle]  0     0    0
#
#   y_PC d_tilt
# 0    0      0

# %%
fig = go.Figure(data=[trace_discr_new, trace_cont])

fig.show()
# Out:
# <div>
#
#
#             <div id="7d20932c-fdbc-49e9-8da1-4786971852f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
320.856947368902, 5322.731319207329, 5324.605691045754, 5326.48006288418, 5328.354434722605, 5330.228806561032, 5332.103178399457, 5333.977550237883, 5335.851922076308, 5337.726293914735, 5339.60066575316, 5341.475037591586, 5343.349409430011, 5345.223781268438, 5347.098153106863, 5348.9725249452895, 5350.846896783714, 5352.721268622141, 5354.595640460566, 5356.4700122989925, 5358.344384137417, 5360.218755975844, 5362.093127814269, 5363.967499652696, 5365.84187149112, 5367.716243329547, 5369.590615167972, 5371.464987006399, 5373.339358844823, 5375.213730683249, 5377.088102521675, 5378.9624743601, 5380.8368461985265, 5382.711218036951, 5384.585589875378, 5386.459961713803, 5388.334 ...

# %% [markdown]
# ### 70 degree incidence

# %%
num_bins = 2000
inc_e = 55000

# old
el = pd.read_hdf('data/Al_BSE_mode:DS_tilt:70.0_tolE:0.0001_tolW:1e-07.h5', 'electrons')

energyDS = list(el[el.outcome=='backscattered']['final_E'])

print ('yield of old discretly scattered BSE', len(energyDS)/inc_e)


#bins_mean = [0.5 * (bins_c[i] + bins_c[i+1]) for i in range(len(n_c)-1)]

n_d, bins_d, patches_d = plt.hist([float(energy) for energy in energyDS], num_bins, facecolor='red', alpha=0.5)

bins_mean = [0.5 * (bins_d[i] + bins_d[i+1]) for i in range(len(n_d)-1)]

trace_discr_old = go.Scatter(x = np.asarray(bins_mean), 
                           y = n_d/inc_e, 
                          marker=dict(
                                 color = 'rgba(10, 174, 212 .9)',),
                          name = 'discrete old',)


# ds
el = pd.read_hdf('data/Al_BSE_mode:DS_tilt:70.0_tolE:0.0001_tolW:1e-07_maxScat:1000.h5', 'electrons')

energyDS = list(el[el.outcome=='backscattered']['final_E'])

print ('yield of new discretly scattered BSE', len(energyDS)/inc_e)


#bins_mean = [0.5 * (bins_c[i] + bins_c[i+1]) for i in range(len(n_c)-1)]

n_d, bins_d, patches_d = plt.hist([float(energy) for energy in energyDS], num_bins, facecolor='red', alpha=0.5)

bins_mean = [0.5 * (bins_d[i] + bins_d[i+1]) for i in range(len(n_d)-1)]

trace_discr_new = go.Scatter(x = np.asarray(bins_mean), 
                           y = n_d/inc_e, 
                          marker=dict(
                                 color = 'rgba(10, 14, 212 .9)',),
                          name = 'discrete new',)


# cont
el = pd.read_hdf('data/Al_BSE_mode:cont_tilt:70.0_tolE:0.0001_tolW:1e-07_maxScat:1000.h5', 'electrons')

energyDS = list(el[el.outcome=='backscattered']['final_E'])

print ('yield of continuously scattered BSE', len(energyDS)/inc_e)


#bins_mean = [0.5 * (bins_c[i] + bins_c[i+1]) for i in range(len(n_c)-1)]

n_d, bins_d, patches_d = plt.hist([float(energy) for energy in energyDS], num_bins, facecolor='red', alpha=0.5)

bins_mean = [0.5 * (bins_d[i] + bins_d[i+1]) for i in range(len(n_d)-1)]

trace_cont = go.Scatter(x = np.asarray(bins_mean), 
                           y = n_d/inc_e, 
                          marker=dict(
                                 color = 'rgba(101, 14, 212 .9)',),
                          name = 'cont',)
# Out:
# yield of old discretly scattered BSE 0.6413272727272727
# yield of new discretly scattered BSE 0.5523818181818182
# yield of continuously scattered BSE 0.5084

# %%
fig = go.Figure(data=[trace_discr_old, trace_discr_new, trace_cont])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8eaa741f0912> in <module>
# ----> 1 fig = go.Figure(data=[trace_discr_old, trace_discr_new, trace_cont])
#       2
#       3 fig.show()
#
# NameError: name 'trace_discr_old' is not defined

# %%
num_bins = 2000
inc_e = 100000

# 
mott_el = pd.read_hdf('../data/Al_BSE_mode:DS_tilt:70.0_Emin:15000.0_E0:20000.0_tolE:0.0001_tolW:1e-07.h5', 'els')
print (len(mott_el))
energyDS = list(mott_el[mott_el.outcome=='bks']['final_E'])

print ('yield of old discretly scattered BSE', len(energyDS)/inc_e)
# Out:
# 100137
# yield of old discretly scattered BSE 0.04554

# %%
mott.head(10)
# Out:
#   outcome       final_E
# 0     abs  16664.359901
# 1     abs  19583.450877
# 2     abs  15135.622105
# 3     abs  15335.322207
# 4     abs  15103.088217
# 5     abs  15057.135518
# 6     abs  16963.337738
# 7     abs  15127.041103
# 8     abs  15723.037840
# 9     abs  15014.373986

# %%
mott_scat = pd.read_hdf('../data/Al_BSE_mode:DS_tilt:70.0_Emin:15000.0_E0:20000.0_tolE:0.0001_tolW:1e-07.h5', 'scats')

# %%
mott_scat.head(10)
# Out:
#     type
# 0   Mott
# 1   Mott
# 2   Mott
# 3  Quinn
# 4  Quinn
# 5  Quinn
# 6   Mott
# 7  Quinn
# 8   Mott
# 9   Mott

# %%
test=pd.read_hdf('../tests/testData/testAngles_DS.temp',)
test.close
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2f7154870673> in <module>
# ----> 1 test=pd.read_hdf('../tests/testData/testAngles_DS.temp',)
#       2 test.close
#
# ~/anaconda3/envs/mc/lib/python3.7/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     387                                      'contains multiple datasets.')
#     388             key = candidate_only_group._v_pathname
# --> 389         return store.select(key, auto_close=auto_close, **kwargs)
#     390     except (ValueError, TypeError):
#     391         # if there is an error, close the store
#
# ~/anaconda3/envs/mc/lib/python3.7/site-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close, **kwargs)
#     738                            chunksize=chunksize, auto_close=auto_close)
#     739
# --> 740         return it.get_result()
#     741
#     742     def select_as_coordinates(
#
# ~/anaconda3/envs/mc/lib/python3.7/site-packages/pandas/io/pytables.py in get_result(self, coordinates)
#    1516
#    1517         # directly return the result
# -> 1518         results = self.func(self.start, self.stop, where)
#    1519         self.close()
#    1520         return results
#
# ~/anaconda3/envs/mc/lib/python3.7/site-packages/pandas/io/pytables.py in func(_start, _stop, _where)
#     731             return s.read(start=_start, stop=_stop,
#     732                           where=_where,
# --> 733                           columns=columns)
#     734
#     735         # create the iterator
#
# ~/anaconda3/envs/mc/lib/python3.7/site-packages/pandas/io/pytables.py in read(self, start, stop, **kwargs)
#    2993             blk_items = self.read_index('block{idx}_items'.format(idx=i))
#    2994             values = self.read_array('block{idx}_values'.format(idx=i),
# -> 2995                                      start=_start, stop=_stop)
#    2996             blk = make_block(values,
#    2997                              placement=items.get_indexer(blk_items))
#
# ~/anaconda3/envs/mc/lib/python3.7/site-packages/pandas/io/pytables.py in read_array(self, key, start, stop)
#    2538
#    2539         if isinstance(node, tables.VLArray):
# -> 2540             ret = node[0][start:stop]
#    2541         else:
#    2542             dtype = getattr(attrs, 'value_type', None)
#
# TypeError: 'NoneType' object is not subscriptable
